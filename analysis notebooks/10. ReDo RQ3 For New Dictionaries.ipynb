# %% [markdown]
# ## 1. Environment Creation
#
# ### 1.1 Library Import

# %%
''' FILE ACCESS '''

import json
import os
import glob
import smart_open

''' DATA QUERYING '''

import regex as re
import pandas as pd
import datetime
from datetime import datetime
from dateutil.parser import parse

''' THEMATIC ANALYSIS '''
from bertopic import BERTopic
#from transformers import AutoModel


''' TEXT PREPROCESSING '''
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
stopwords = set(stopwords.words('english'))
import regex as re

''' DATA VISUALIZATION '''

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sb
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\natal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\natal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 2. Data Import

# %%
## Bluesky Posts
jan_ninth = pd.read_csv("Climate Posts January 9th.csv")

# %%
## News Headlines 
headlines = pd.read_excel("Climate Headlines - January 9th.xlsx")

# %%
## Dropping the unneeded index files
jan_ninth.drop(columns='Unnamed: 0',inplace=True)

headlines.drop(columns='Unnamed: 0',inplace=True)

# %%
jan_ninth.head(1)
# Out:
#                                                 text  \
# 0  There's a lot of things I haven't digested yet...
#
#                  created_at                 author  \
# 0  2025-01-09T16:00:02.784Z  kaydegard.bsky.social
#
#                                                  uri  has_images reply_to
# 0  at://did:plc:6f45finsqvrrozxtzyacjbte/app.bsky...       False      NaN

# %% [markdown]
# ### 2.1 Removing Numbers + Punctuation

# %%
def number_remover(text):
    new_text = re.sub("\d","",text)
    clean_text = re.sub("[.,?!#$%]","",new_text)
    return (clean_text)

# %%
jan_ninth['clean text'] = jan_ninth['text'].apply(lambda x: number_remover(x))
headlines['clean text'] = headlines['headline clean'].apply(lambda x: number_remover(x))

# %% [markdown]
# ### 2.2 Creating a corpus for January 9th

# %%
corpus = jan_ninth.copy()

# %%
### POST ANALYSIS FIGURE REDOING
topic_model = BERTopic.load("nataliecastro/bsky-posts-climate")

# %% [markdown]
# ## 3. Dictionary Analysis
#
# ### 3.1 Dictionary Definition
#
# The core themes of our dictionaries for this analysis are as follows: climate change, science, policy mangagement, Republican, Democrat, current politics (centered around our data collection dates), and current moment
#
# The dictionaries from this section were inspired by the work completed in Molder & Calice and Chinn et al.

# %%
climate_change = ["global warming","climate change","greenhouse gas","greenhouse gases"]

policy_management = ["policy","legislation","FEMA","management","disaster respons",'government']

republican = ['republican','republicans','GOP','conservative','conservatives','MAGA']

democrat = ['democrat','democrats','liberal','liberals',"DNC"]

climate_action = ['climate activism','climate change legislation', 'climate change policy action','climate protest']

environmental_justice = ['environmental justice','climate justice','just transition','climate equity','climate equality']

climate_resilience = ['climate resilience','climate hope','climate communities','climate cafe']

# %%
word_list_nested = [climate_change,policy_management,republican,democrat,climate_action,environmental_justice,climate_resilience]

# %%
seed_topics = [climate_change,policy_management,republican,democrat,climate_action,environmental_justice,climate_resilience]

# %%
climate_words = []
for wl in word_list_nested:
    for word in wl:
        climate_words.append(word)

# %%
word_counter = {}

for word in climate_words:
    word_counter[word] = 0

# %%
word_counter
# Out:
# {'global warming': 0,
#  'climate change': 0,
#  'greenhouse gas': 0,
#  'greenhouse gases': 0,
#  'policy': 0,
#  'legislation': 0,
#  'FEMA': 0,
#  'management': 0,
#  'disaster respons': 0,
#  'government': 0,
#  'republican': 0,
#  'republicans': 0,
#  'GOP': 0,
#  'conservative': 0,
#  'conservatives': 0,
#  'MAGA': 0,
#  'democrat': 0,
#  'democrats': 0,
#  'liberal': 0,
#  'liberals': 0,
#  'DNC': 0,
#  'climate activism': 0,
#  'climate change legislation': 0,
#  'climate change policy action': 0,
#  'climate protest': 0,
#  'environmental justice': 0,
#  'climate justice': 0,
#  'just transition': 0,
#  'climate equity': 0,
#  'climate equality': 0,
#  'climate resilience': 0,
#  'climate hope': 0,
#  'climate communities': 0,
#  'climate cafe': 0}

# %% [markdown]
# ## 3. Topic Modeling

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english",decode_error='replace',strip_accents='ascii',
                                  lowercase=True)
topic_model = BERTopic(vectorizer_model=vectorizer_model,verbose=True,seed_topic_list=seed_topics)

# %%
docs = corpus['clean text'].to_list()
  ## Using model.fit_transform, to apply to the list of documents. This will both embedd and assign topics to the texts in the document lists.
topics, probs = topic_model.fit_transform(docs)

# %%
cleaned_topics = topic_model.reduce_outliers(docs, topics)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:06<00:00,  1.94it/s]

# %%
topic_model.update_topics(docs, topics=cleaned_topics)
# Out:
# 2025-02-03 00:36:17,819 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
topic_info = topic_model.get_topic_info()

# %%
topic_info
# Out:
#      Topic  Count                                               Name  \
# 0       -1     18  -1_climatescam_nbaustraliainstituteorgauclimat...
# 1        0    784                0_insurance_companies_risk_insurers
# 2        1    886                            1_fossil_fuel_fuels_oil
# 3        2    519                                2_ai_data_use_using
# 4        3    882              3_california_fires_wildfires_southern
# ..     ...    ...                                                ...
# 280    279     17                279_ghg_utilization_hydrogen_mnchen
# 281    280     26                    280_threelegged_wake_night_fell
# 282    281     29     281_florida_denialism_miccosukee_cuntservative
# 283    282     27                       282_obama_person_walked_halo
# 284    283     22           283_hostility_offering_politely_priority
#
#                                         Representation  \
# 0    [climatescam, nbaustraliainstituteorgauclimate...
# 1    [insurance, companies, risk, insurers, areas, ...
# 2    [fossil, fuel, fuels, oil, industry, burning, ...
# 3    [ai, data, use, using, tech, centers, energy, ...
# 4    [california, fires, wildfires, southern, ca, c...
# ..                                                 ...
# 280  [ghg, utilization, hydrogen, mnchen, informati...
# 281  [threelegged, wake, night, fell, asleep, middl...
# 282  [florida, denialism, miccosukee, cuntservative...
# 283  [obama, person, walked, halo, ken, jennings, e...
# 284  [hostility, offering, politely, priority, reap...
#
#                                    Representative_Docs
# 0    [How climate change impacts wildfires\n\nClima...
# 1    [Even the Insurance companies believe in clima...
# 2    [And we need to stop burning fossil fuels, Its...
# 3    [Researchers believe that each string of promp...
# 4    [Wildfires continue across Southern California...
# ..                                                 ...
# 280  [Sure but e-fuels made from hydrogen require D...
# 281  [Holy fuck  Id love to have you sit back and f...
# 282  [In Florida the Miccosukee fight to protect th...
# 283  [love to live on earth  where a screen shot fr...
# 284  [Like Im no climate scientist but just maybe s...
#
# [285 rows x 5 columns]

# %% [markdown]
# ### 3.1 Saving the Model to HuggingFace

# %%
from huggingface_hub import login

# %%
login()

# %%
topic_model.save("bsky-posts-climate",serialization='pickle',save_embedding_model=True,save_ctfidf=True,)
# Out:
# 2025-02-03 01:32:20,835 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# C:\Users\natal\miniconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
# Push to HuggingFace Hub
topic_model.push_to_hf_hub(
    repo_id="nataliecastro/bsky-posts-climate",
    save_ctfidf=True,
    private=True,
    commit_message='Adding January 9th climate related posts',
    save_embedding_model=True,
)

# %% [markdown]
# ### 4.2 Identifying Semantically Related Topics

# %%
semantic_topics_nested = []
for word in climate_words:
    related_tuple = topic_model.find_topics(search_term=word)
    related_topics = related_tuple[0]
    
    semantic_topics_nested.append(related_topics)
    
semantic_topics = sum(semantic_topics_nested, [])

# %%
semantic_topics = list(set(semantic_topics))

# %%
len(semantic_topics)
# Out:
# 50

# %%
climate_topic_info = []

for topic in semantic_topics:
    current_info = topic_model.get_topic_info(topic)
    climate_topic_info.append(current_info)
    
climate_topics = pd.concat(climate_topic_info)

# %%
semantic_topics_nested = []
for word in climate_words:
    related_tuple = topic_model.find_topics(search_term=word)
    related_topics = related_tuple[0]
    
    semantic_topics_nested.append(related_topics)
    
semantic_topics = sum(semantic_topics_nested, [])

# %%
labels = {}
for nest in range(0,len(semantic_topics_nested)):
    topic_nest = semantic_topics_nested[nest]
    related_word = climate_words[nest]
    
    labels[related_word] = topic_nest

# %%
labels
# Out:
# {'global warming': [71, 256, 28, 45, 59],
#  'climate change': [256, 174, 71, 45, 189],
#  'greenhouse gas': [45, 94, 250, 147, 256],
#  'greenhouse gases': [45, 94, 250, 147, 256],
#  'policy': [0, 283, 197, 195, 13],
#  'legislation': [261, 171, 220, 161, 283],
#  'FEMA': [92, 20, 276, 231, 23],
#  'management': [30, 84, 67, 220, 32],
#  'disaster respons': [23, 82, 4, 65, 10],
#  'government': [67, 69, 114, 84, 195],
#  'republican': [26, 130, 69, 238, 20],
#  'republicans': [26, 130, 69, 238, 20],
#  'GOP': [26, 130, 69, 238, 20],
#  'conservative': [238, 26, 130, 69, 20],
#  'conservatives': [238, 26, 130, 69, 20],
#  'MAGA': [92, 20, 231, 252, 259],
#  'democrat': [26, 69, 130, 238, 114],
#  'democrats': [26, 130, 69, 238, 114],
#  'liberal': [238, 26, 130, 69, 163],
#  'liberals': [238, 26, 130, 69, 163],
#  'DNC': [69, 26, 130, 276, 238],
#  'climate activism': [256, 13, 174, 45, 7],
#  'climate change legislation': [256, 174, 147, 45, 171],
#  'climate change policy action': [256, 174, 147, 13, 32],
#  'climate protest': [256, 13, 174, 45, 177],
#  'environmental justice': [17, 32, 147, 18, 7],
#  'climate justice': [256, 17, 174, 45, 177],
#  'just transition': [257, 273, 33, 249, 71],
#  'climate equity': [256, 45, 174, 177, 32],
#  'climate equality': [256, 174, 147, 177, 71],
#  'climate resilience': [256, 4, 174, 32, 65],
#  'climate hope': [256, 174, 8, 65, 189],
#  'climate communities': [256, 174, 200, 65, 45],
#  'climate cafe': [256, 7, 174, 45, 189]}

# %%
climate_change_topics = [71, 256, 28, 45, 59,174,189, 94, 250, 147]

policy_management_topics = [0, 283, 197, 195, 13, 261, 171, 220, 161, 92, 20, 276, 231, 23, 30, 84, 67, 220, 32, 82, 4, 65, 10,69, 114]

republican_topics = [26, 130, 69, 238, 20,92,231,252,259]

democrat_topics = [26, 69, 130, 238, 114,163,276]

climate_action_topics = [256, 13, 174, 45, 7,147, 171, 32,177]

environmental_justice_topics = [17, 32, 147, 18, 7, 256, 174, 45, 177,257, 273, 33, 249, 71]

climate_resilience_topics = [256, 4, 174, 32, 8, 65, 189,200, 65, 45,7]

# %%
climate_topics = climate_topics.sort_values(by='Count',ascending=False)

# %%
climate_topics
# Out:
#    Topic  Count                                               Name  \
# 0      0    784                0_insurance_companies_risk_insurers
# 0     33    695                        33_change_climate_about_not
# 0      4    509             4_resilience_mental_strength_community
# 0      8    452                           8_drought_water_rain_dry
# 0     71    352                            71_warming_global_is_it
# 0     10    318          10_earthquake_earthquakes_zone_northridge
# 0      7    283          7_earthy_greenhouse_sustainability_coffee
# 0     13    236               13_action_protest_activism_activists
# 0     18    227        18_biodiversity_conservation_species_nature
# 0     32    219    32_sustainability_sustainable_goals_development
# 0     28    217                            28_warming_cold_up_warm
# 0     26    208            26_republicans_democrats_republican_gop
# 0     82    208                82_crisis_crises_climate_escalating
# 0     17    172                    17_justice_court_disability_ipl
# 0     65    158               65_floods_hurricanes_droughts_storms
# 0     20    156                     20_maga_earth_trump_republican
# 0     30    153       30_corporate_corporations_business_employees
# 0     45    153                  45_greenhouse_atmosphere_gases_co
# 0     23    131                      23_earthquake_codes_fire_iron
# 0     67    107                   67_budget_department_police_lafd
# 0     59    106             59_exceeded_warming_temperatures_limit
# 0    147    103                   147_emissions_reduce_co_aviation
# 0     92     91                            92_maga_cult_hoax_trump
# 0    261     82              261_nature_tackle_legislation_reading
# 0     84     81           84_capitalism_capitalist_stage_latestage
# 0    114     80                    114_vote_voting_elected_deniers
# 0    174     73  174_climatechange_patreoncomglenlelievre_patre...
# 0     69     72                       69_rock_party_dems_political
# 0    250     66                   250_emissions_greenhouse_gas_cut
# 0    161     60         161_young_activists_politics_fundamentally
# 0    189     59                    189_cold_climates_winter_always
# 0     94     57                      94_carbon_dioxide_carbyne_gas
# 0    273     52                273_changing_human_godzilla_playing
# 0    197     50             197_warnings_decades_turbulent_heading
# 0    249     46                           249_safe_live_stay_leave
# 0    256     45  256_climateemergency_climatecrisis_climatecata...
# 0    252     42                252_fox_news_politicize_reinstitute
# 0    220     37       220_infrastructure_designed_situations_roads
# 0    171     35  171_wwwthegodpodcastcompclimatech_workshop_mic...
# 0    238     35            238_conservatives_blaming_floors_result
# 0    130     34        130_republicans_democrats_acknowledge_fires
# 0    163     32              163_trans_genocide_minority_political
# 0    257     30            257_resilient_societies_transition_otto
# 0    177     27  177_follow_climatehumanbskysocial_ucalgarybsky...
# 0    195     26                   195_controls_trump_weaken_cooler
# 0    200     26                       200_season_map_rainy_drought
# 0    259     24                    259_nia_emerged_pacific_pattern
# 0    283     22           283_hostility_offering_politely_priority
# 0    231     20                     231_maga_answers_loved_paywall
# 0    276     14                           276_camp_mlk_depts_trump
#
#                                       Representation  Representative_Docs
# 0  [insurance, companies, risk, insurers, areas, ...                  NaN
# 0  [change, climate, about, not, it, its, is, do,...                  NaN
# 0  [resilience, mental, strength, community, your...                  NaN
# 0  [drought, water, rain, dry, droughts, conditio...                  NaN
# 0  [warming, global, is, it, then, its, that, abo...                  NaN
# 0  [earthquake, earthquakes, zone, northridge, br...                  NaN
# 0  [earthy, greenhouse, sustainability, coffee, m...                  NaN
# 0  [action, protest, activism, activists, petitio...                  NaN
# 0  [biodiversity, conservation, species, nature, ...                  NaN
# 0  [sustainability, sustainable, goals, developme...                  NaN
# 0  [warming, cold, up, warm, morning, freezing, m...                  NaN
# 0  [republicans, democrats, republican, gop, suff...                  NaN
# 0  [crisis, crises, climate, escalating, we, our,...                  NaN
# 0  [justice, court, disability, ipl, andy, fight,...                  NaN
# 0  [floods, hurricanes, droughts, storms, tornado...                  NaN
# 0  [maga, earth, trump, republican, crimes, his, ...                  NaN
# 0  [corporate, corporations, business, employees,...                  NaN
# 0  [greenhouse, atmosphere, gases, co, methane, d...                  NaN
# 0  [earthquake, codes, fire, iron, resilience, ki...                  NaN
# 0  [budget, department, police, lafd, cut, fire, ...                  NaN
# 0  [exceeded, warming, temperatures, limit, coper...                  NaN
# 0  [emissions, reduce, co, aviation, reductions, ...                  NaN
# 0  [maga, cult, hoax, trump, magas, deniers, care...                  NaN
# 0  [nature, tackle, legislation, reading, bill, r...                  NaN
# 0  [capitalism, capitalist, stage, latestage, cap...                  NaN
# 0  [vote, voting, elected, deniers, citizens, vot...                  NaN
# 0  [climatechange, patreoncomglenlelievre, patreo...                  NaN
# 0  [rock, party, dems, political, democrat, democ...                  NaN
# 0  [emissions, greenhouse, gas, cut, stalled, eff...                  NaN
# 0  [young, activists, politics, fundamentally, no...                  NaN
# 0  [cold, climates, winter, always, leaves, whoa,...                  NaN
# 0  [carbon, dioxide, carbyne, gas, fertilizer, em...                  NaN
# 0  [changing, human, godzilla, playing, impossibl...                  NaN
# 0  [warnings, decades, turbulent, heading, knowle...                  NaN
# 0  [safe, live, stay, leave, doors, wish, family,...                  NaN
# 0  [climateemergency, climatecrisis, climatecatas...                  NaN
# 0  [fox, news, politicize, reinstitute, trump, di...                  NaN
# 0  [infrastructure, designed, situations, roads, ...                  NaN
# 0  [wwwthegodpodcastcompclimatech, workshop, micr...                  NaN
# 0  [conservatives, blaming, floors, result, liber...                  NaN
# 0  [republicans, democrats, acknowledge, fires, p...                  NaN
# 0  [trans, genocide, minority, political, women, ...                  NaN
# 0  [resilient, societies, transition, otto, halt,...                  NaN
# 0  [follow, climatehumanbskysocial, ucalgarybskys...                  NaN
# 0  [controls, trump, weaken, cooler, science, rul...                  NaN
# 0  [season, map, rainy, drought, complicates, cal...                  NaN
# 0  [nia, emerged, pacific, pattern, noaa, tropica...                  NaN
# 0  [hostility, offering, politely, priority, reap...                  NaN
# 0  [maga, answers, loved, paywall, ones, shits, f...                  NaN
# 0  [camp, mlk, depts, trump, ca, cbc, inauguratio...                  NaN

# %%
climate_topics.to_csv("BlueSky Climate Topic List - Climate Focusing Event.csv")

# %% [markdown]
# ### 4.3 Matching Document To Topic

# %%
document_info = topic_model.get_document_info(docs)

# %%
topic_filtered = []

for topic in semantic_topics:
    current_condition = document_info['Topic'] == topic
    current_documents = document_info[current_condition]
    
    topic_filtered.append(current_documents)
    
climate_document_info = pd.concat(topic_filtered)

# %%
topic_counts = climate_document_info['Name'].value_counts()

# %%
document_frequencies = pd.DataFrame(topic_counts)

# %%
document_frequencies['Percentage'] = document_frequencies['Name'].apply(lambda x: x/8194)

# %%
document_frequencies.reset_index(inplace=True)

# %%
document_frequencies.rename(columns={"index":"Name","Name":"Frequnecy",},inplace=True)

# %%
name_and_topic = climate_document_info[['Topic','Name']].copy().drop_duplicates()

# %%
document_frequencies = document_frequencies.merge(right=name_and_topic,on='Name')

# %%
document_frequencies.head()
# Out:
#                                               Name  Frequnecy  Percentage  \
# 0          26_republicans_democrats_republican_gop       2080    0.253844
# 1                45_greenhouse_atmosphere_gases_co       1683    0.205394
# 2                          71_warming_global_is_it       1408    0.171833
# 3  32_sustainability_sustainable_goals_development       1095    0.133634
# 4                   20_maga_earth_trump_republican       1092    0.133268
#
#    Topic
# 0     26
# 1     45
# 2     71
# 3     32
# 4     20

# %% [markdown]
# ### 4.4 Counting Instances Per Dictionary

# %%
def dictionary_filter(topic_dictionary):
    frequencies = []
    for topic in topic_dictionary:
        topic_condition = document_frequencies['Topic'] == topic
        
        current_frequency = document_frequencies[topic_condition]
        frequency = current_frequency.iloc[0,1]

        current_frequency = {"topic":topic,"frequency":frequency}
        
        frequencies.append(current_frequency)
        
    return (pd.DataFrame(frequencies))

# %%
''' COPIED FROM ABOVE'''
climate_change_topics = [71, 256, 28, 45, 59,174,189, 94, 250, 147]

policy_management_topics = [0, 283, 197, 195, 13, 261, 171, 220, 161, 92, 20, 276, 231, 23, 30, 84, 67, 220, 32, 82, 4, 65, 10,69, 114]

republican_topics = [26, 130, 69, 238, 20,92,231,252,259]

democrat_topics = [26, 69, 130, 238, 114,163,276]

climate_action_topics = [256, 13, 174, 45, 7,147, 171, 32,177]

environmental_justice_topics = [17, 32, 147, 18, 7, 256, 174, 45, 177,257, 273, 33, 249, 71]

climate_resilience_topics = [256, 4, 174, 32, 8, 65, 189,200, 65, 45,7]

# %%
climate_change_freqs = dictionary_filter(climate_change_topics)
policy_freqs = dictionary_filter(policy_management_topics)
republican_freqs = dictionary_filter(republican_topics)
democrat_freqs = dictionary_filter(democrat_topics)
ca_freqs = dictionary_filter(climate_action_topics)
ej_freqs = dictionary_filter(environmental_justice_topics)
cr_freqs = dictionary_filter(climate_resilience_topics)

frequencies = [climate_change_freqs,
policy_freqs,
republican_freqs,
democrat_freqs,
ca_freqs,
ej_freqs,
cr_freqs,]

# %%
dictionary_names = ["Climate\nChange",'Policy\nManagement','Republican','Democrat','Climate\nAction','Environmental\nJustice','Climate\nResilience']

# %%
dictionary_values = []
for i in range(0,len(dictionary_names)):
    current_dictionary = dictionary_names[i]
    
    current_freq = frequencies[i]
    desc = current_freq.describe()
    mean = desc.iloc[1,1]
    min_ = desc.iloc[3,1]
    max_ = desc.iloc[7,1]
    freq = current_freq['frequency'].sum()
    
    dictionary_topic_info = {"Dictionary":current_dictionary,"Total Frequency":freq,
                            "Average Topic Size":mean,"Maximum Topic Size":max_,"Minimum Topic Size":min_}
    
    dictionary_values.append(dictionary_topic_info)
    
    print (current_dictionary,"-----------------")
    print (f"Total Frequency: {freq}\nMean: {mean}\nMin: {min_}\nMax: {max_}\n")
# Out:
# Climate
# Change -----------------
# Total Frequency: 6006
# Mean: 600.6
# Min: 106.0
# Max: 1683.0
#
# Policy
# Management -----------------
# Total Frequency: 8670
# Mean: 346.8
# Min: 28.0
# Max: 1095.0
#
# Republican -----------------
# Total Frequency: 4942
# Mean: 549.1111111111111
# Min: 24.0
# Max: 2080.0
#
# Democrat -----------------
# Total Frequency: 3894
# Mean: 556.2857142857143
# Min: 28.0
# Max: 2080.0
#
# Climate
# Action -----------------
# Total Frequency: 6918
# Mean: 768.6666666666666
# Min: 70.0
# Max: 1683.0
#
# Environmental
# Justice -----------------
# Total Frequency: 8706
# Mean: 621.8571428571429
# Min: 30.0
# Max: 1683.0
#
# Climate
# Resilience -----------------
# Total Frequency: 8115
# Mean: 737.7272727272727
# Min: 26.0
# Max: 1683.0

# %%
values = pd.DataFrame(dictionary_values).sort_values(by='Total Frequency',ascending=False)
values
# Out:
#                Dictionary  Total Frequency  Average Topic Size  \
# 5  Environmental\nJustice             8706          621.857143
# 1      Policy\nManagement             8670          346.800000
# 6     Climate\nResilience             8115          737.727273
# 4         Climate\nAction             6918          768.666667
# 0         Climate\nChange             6006          600.600000
# 2              Republican             4942          549.111111
# 3                Democrat             3894          556.285714
#
#    Maximum Topic Size  Minimum Topic Size
# 5              1683.0                30.0
# 1              1095.0                28.0
# 6              1683.0                26.0
# 4              1683.0                70.0
# 0              1683.0               106.0
# 2              2080.0                24.0
# 3              2080.0                28.0

# %%
sb.set_style("white")
sb.set(font='Times New Roman', font_scale=1.2)
fig, ax = plt.subplots(figsize=(12,5 )) 



hist = sb.barplot(values,x="Dictionary",y="Total Frequency",color="black")


for bar_group in hist.containers:  # `containers` contains the histogram bars grouped by hue
    # Get heights and centers for each group
    heights = [bar.get_height() for bar in bar_group]
    centers = [bar.get_x() + bar.get_width() / 2 for bar in bar_group]
    
    # Add markers
    plt.scatter(centers, heights, color='black', zorder=3)
    
    for center, height in zip(centers, heights):
        plt.text(
            center, 
            height, 
            f'{int(height):,}',  # Format with commas
            color='black', 
            ha='center', 
            va='bottom', 
            fontsize=10
        )

for container in hist.containers:
    hist.bar_label(container, fmt='%d', label_type='edge', padding=3, bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))

hist.set_title("Climate Focusing Event: BlueSky Post Distribution")
hist.set_xlabel("")
hist.set_ylabel("Posts")
ax.tick_params(axis='x')
ax.grid(True)
ax.set_facecolor("white")

formatter = FuncFormatter(lambda x, _: f'{int(x):,}')
ax.yaxis.set_major_formatter(formatter)


# Set the border (box) around the entire plot
for spine in ax.spines.values():
    spine.set_edgecolor('black')  # Set the color of the border to black
    spine.set_linewidth(1)  # Set the width of the border

plt.tight_layout()
plt.savefig("Climate Focusing Events-  BlueSky Post Distribution.png",dpi=2500)
plt.show();

# %% [markdown]
# ### 4.5 Visualizing the Top N Most Frequent Terms for Climate Policy Dictionary

# %%
''' PARSING THROUGH THE DATAFRAME TO MAKE A LIST OF ALL OF THE DOCUMENTS THAT ARE IN POLICY MANAGEMENT '''

policy_documents =document_info[document_info['Topic'].isin(policy_management_topics)]
policy_documents.reset_index(inplace=True)
policy_documents.drop(columns='index',inplace=True)

# %%
topn_words = policy_documents['Document'].to_list()

# %%
joined_list = ' '.join(topn_words)
policy_words = joined_list.split(" ")

# %%
## Removing stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

stop_words.update(["the","like","it"])

## Stemming the words so morphemes are counted together
from nltk.stem import PorterStemmer
ps = PorterStemmer()

stemmed_words = []
for word in policy_words:
    if word not in stop_words:
        if word != "":
            if word != "&":
                if word != "-":
                    stem = ps.stem(word)

                    stemmed_words.append(stem)

# %%
from collections import Counter

c = Counter(stemmed_words)

# %%
policy_wcs = pd.DataFrame(c.items(), columns=['Word', 'Count'])

# %%
policy_wcs.sort_values(by='Count',ascending=False,inplace=True)
policy_data = policy_wcs.head(30)

# %%
policy_data.reset_index(inplace=True)

# %%
policy_data.drop(index=[4,20],inplace=True)

# %%
policy_data
# Out:
#     index       Word  Count
# 0      31     climat   2059
# 1      32      chang   1124
# 2      68          i    862
# 3     180      insur    767
# 5      42       fire    501
# 6     312     resili    459
# 7     182      peopl    375
# 8      43  earthquak    354
# 9     156    compani    309
# 10    403        get    293
# 11    431        one    285
# 12     40         go    270
# 13    116         us    269
# 14    243       make    267
# 15    170       need    264
# 16    100      crisi    261
# 17      9    sustain    256
# 18    230      earth    245
# 19   1268       risk    238
# 21    144      think    221
# 22    192       year    221
# 23      2       live    207
# 24     19       time    207
# 25    222      build    190
# 26     88      flood    190
# 27     36        new    189
# 28    439       home    188
# 29    242      would    187

# %%
sb.set_style("white")
sb.set(font='Times New Roman', font_scale=1.2)
fig, ax = plt.subplots(figsize=(5,9 )) 



hist = sb.barplot(policy_data,x="Count",y="Word",color="black")


'''for bar_group in hist.containers:  # `containers` contains the histogram bars grouped by hue
    # Get heights and centers for each group
    heights = [bar.get_height() for bar in bar_group]
    centers = [bar.get_x() + bar.get_width() / 2 for bar in bar_group]
    
    # Add markers
    plt.scatter(centers, heights, color='black', zorder=3)
    
    for center, height in zip(centers, heights):
        plt.text(
            center, 
            height, 
            f'{int(height):,}',  # Format with commas
            color='black', 
            ha='center', 
            va='bottom', 
            fontsize=10
        )

for container in hist.containers:
    hist.bar_label(container, fmt='%d', label_type='edge', padding=3, bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
'''

for container in hist.containers:
    hist.bar_label(container, fmt='%d', label_type='edge', padding=3, bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
hist.set_title("Climate Focusing Event:\nTop Words in Climate Policy Theme")
hist.set_xlabel("")
hist.set_ylabel("Word Count")
ax.tick_params(axis='x')
ax.grid(True)
ax.set_facecolor("white")

'''formatter = FuncFormatter(lambda x, _: f'{int(x):,}')
ax.yaxis.set_major_formatter(formatter)'''


# Set the border (box) around the entire plot
for spine in ax.spines.values():
    spine.set_edgecolor('black')  # Set the color of the border to black
    spine.set_linewidth(1)  # Set the width of the border

plt.tight_layout()
plt.savefig("Climate Focusing Events- Top Words in Climate Policy Theme.png",dpi=2500)
plt.show();

# %% [markdown]
# ## 5. Fitting the News Documents Into The Corpus

# %%
headlines.head(1)
# Out:
#                                     source tag  \
# 0  https://www.nytimes.com/section/climate   a
#
#                                            headlines  \
# 0  <a class="css-1326lay e5h2ety0" href="https://...
#
#                                       headline clean  \
# 0  <i class="css-1qtg4z6"></i><span aria-hidden="...
#
#                                           clean text
# 0  <i class="css-qtgz"></i><span aria-hidden="tru...

# %%
headlines['clean text'] = headlines['headline clean'].apply(lambda x: number_remover(x))
headlines.drop_duplicates(subset='clean text',inplace=True)
news = headlines['clean text'].to_list()

# %%
print (len(news))
# Out:
# 99

# %%
''' 99 HEADLINES FROM JAN 6 & JAN 20 THAT ARE NOT DUPLICATES'''

# %%
probable_news_topics = []
for headline in news:
    current_topic, similarity = topic_model.find_topics(headline,top_n=1)
    probable_news_topics.append(current_topic[0])

# %%
''' CREATING THE DATAFRAME '''
news_topics = pd.DataFrame()
news_topics['Headline'] = news
news_topics['Topic'] = probable_news_topics

# %%
''' FINDING THE TOPIC NAMES'''
topic_info = topic_model.get_topic_info()
topic_names = topic_info[['Topic','Name']]

# %%
''' MERGING TOPIC NAMES TO NEWS HEADLINES '''
news_topics = news_topics.merge(right=topic_names,on='Topic')

# %%
value_counts = pd.DataFrame(news_topics.value_counts("Name"))

# %%
## Fixing the indices
value_counts.reset_index(inplace=True)

# %%
value_counts.rename(columns={"Name":"Name",0:"Frequency"},inplace=True)

# %%
value_counts['Percentage'] = value_counts['Frequency'] / 99 ## value here is generated based on the

# %%
value_counts
# Out:
#                                                  Name  Frequency  Percentage
# 0   256_climateemergency_climatecrisis_climatecata...         40    0.404040
# 1                 0_insurance_companies_risk_insurers          5    0.050505
# 2                    147_emissions_reduce_co_aviation          5    0.050505
# 3                44_deforestation_palm_amazon_cbdnews          5    0.050505
# 4     32_sustainability_sustainable_goals_development          4    0.040404
# 5               3_california_fires_wildfires_southern          4    0.040404
# 6                            8_drought_water_rain_dry          3    0.030303
# 7                     11_pollution_air_health_mercury          3    0.030303
# 8                65_floods_hurricanes_droughts_storms          3    0.030303
# 9                 5_energy_renewable_renewables_solar          3    0.030303
# 10                 21_fossils_fossil_fossilized_found          2    0.020202
# 11                   73_heartwarming_heart_story_love          2    0.020202
# 12    162_hydrants_water_laistcomnewsclimate_pressure          1    0.010101
# 13           51_wildfire_wildfires_increase_increased          1    0.010101
# 14                85_tibet_earthquake_survivors_quake          1    0.010101
# 15                    75_footprint_carbon_reduce_idea          1    0.010101
# 16                       74_russian_ukraine_russia_eu          1    0.010101
# 17                    6_greenland_rare_minerals_wants          1    0.010101
# 18                     64_gaza_genocide_palestine_war          1    0.010101
# 19          57_whiplash_hydroclimate_wet_intensifying          1    0.010101
# 20             4_resilience_mental_strength_community          1    0.010101
# 21                   16_hottest_year_record_threshold          1    0.010101
# 22                             47_musk_elon_musks_his          1    0.010101
# 23                       111_limit_pass_first_warming          1    0.010101
# 24          10_earthquake_earthquakes_zone_northridge          1    0.010101
# 25                      34_cost_expensive_costs_money          1    0.010101
# 26                         31_meat_vegan_animal_dairy          1    0.010101
# 27               13_action_protest_activism_activists          1    0.010101
# 28           24_forests_forest_management_faoforestry          1    0.010101
# 29                            1_fossil_fuel_fuels_oil          1    0.010101
# 30                 193_earthworms_earthworm_dirt_soil          1    0.010101
# 31                      94_carbon_dioxide_carbyne_gas          1    0.010101

# %%
def topic_num(topic_name):
    pattern = r"[0-9]{1,3}"
    
    found = re.findall(pattern,topic_name)
    string_found = found[0]
    int_found = int(string_found)
    return (int_found)

# %%
value_counts['Topic'] = value_counts['Name'].apply(lambda x: topic_num(x))

# %%
def dictionary_filter(topic_dictionary):
    frequencies = []
    for topic in topic_dictionary:
        topic_condition = value_counts['Topic'] == topic
        
        current_frequency = value_counts[topic_condition]
        if len(current_frequency) != 0:
            frequency = current_frequency.iloc[0,1]

            current_frequency = {"topic":topic,"frequency":frequency}
           
        else:
            current_frequency = {"topic":topic,"frequency":0}
            
            
        frequencies.append(current_frequency)
        
    return (pd.DataFrame(frequencies))

# %%
climate_change_freqs = dictionary_filter(climate_change_topics)
policy_freqs = dictionary_filter(policy_management_topics)
republican_freqs = dictionary_filter(republican_topics)
democrat_freqs = dictionary_filter(democrat_topics)
ca_freqs = dictionary_filter(climate_action_topics)
ej_freqs = dictionary_filter(environmental_justice_topics)
cr_freqs = dictionary_filter(climate_resilience_topics)

frequencies = [climate_change_freqs,
policy_freqs,
republican_freqs,
democrat_freqs,
ca_freqs,
ej_freqs,
cr_freqs,]

# %%
dictionary_values = []
for i in range(0,len(dictionary_names)):
    current_dictionary = dictionary_names[i]
    
    current_freq = frequencies[i]
    desc = current_freq.describe()
    mean = desc.iloc[1,1]
    min_ = desc.iloc[3,1]
    max_ = desc.iloc[7,1]
    freq = current_freq['frequency'].sum()
    
    dictionary_topic_info = {"Dictionary":current_dictionary,"Total Frequency":freq,
                            "Average Topic Size":mean,"Maximum Topic Size":max_,"Minimum Topic Size":min_}
    
    dictionary_values.append(dictionary_topic_info)
    
    print (current_dictionary,"-----------------")
    print (f"Total Frequency: {freq}\nMean: {mean}\nMin: {min_}\nMax: {max_}\n")
# Out:
# Climate
# Change -----------------
# Total Frequency: 46
# Mean: 4.6
# Min: 0.0
# Max: 40.0
#
# Policy
# Management -----------------
# Total Frequency: 15
# Mean: 0.6
# Min: 0.0
# Max: 5.0
#
# Republican -----------------
# Total Frequency: 0
# Mean: 0.0
# Min: 0.0
# Max: 0.0
#
# Democrat -----------------
# Total Frequency: 0
# Mean: 0.0
# Min: 0.0
# Max: 0.0
#
# Climate
# Action -----------------
# Total Frequency: 50
# Mean: 5.555555555555555
# Min: 0.0
# Max: 40.0
#
# Environmental
# Justice -----------------
# Total Frequency: 49
# Mean: 3.5
# Min: 0.0
# Max: 40.0
#
# Climate
# Resilience -----------------
# Total Frequency: 54
# Mean: 4.909090909090909
# Min: 0.0
# Max: 40.0

# %%
values = pd.DataFrame(dictionary_values).sort_values(by='Total Frequency',ascending=False)
values
# Out:
#                Dictionary  Total Frequency  Average Topic Size  \
# 6     Climate\nResilience               54            4.909091
# 4         Climate\nAction               50            5.555556
# 5  Environmental\nJustice               49            3.500000
# 0         Climate\nChange               46            4.600000
# 1      Policy\nManagement               15            0.600000
# 2              Republican                0            0.000000
# 3                Democrat                0            0.000000
#
#    Maximum Topic Size  Minimum Topic Size
# 6                40.0                 0.0
# 4                40.0                 0.0
# 5                40.0                 0.0
# 0                40.0                 0.0
# 1                 5.0                 0.0
# 2                 0.0                 0.0
# 3                 0.0                 0.0

# %%
sb.set_style("white")
sb.set(font='Times New Roman', font_scale=1.2)
fig, ax = plt.subplots(figsize=(12,5 )) 



hist = sb.barplot(values,x="Dictionary",y="Total Frequency",color="black")


for bar_group in hist.containers:  # `containers` contains the histogram bars grouped by hue
    # Get heights and centers for each group
    heights = [bar.get_height() for bar in bar_group]
    centers = [bar.get_x() + bar.get_width() / 2 for bar in bar_group]
    
    # Add markers
    plt.scatter(centers, heights, color='black', zorder=3)
    
    for center, height in zip(centers, heights):
        plt.text(
            center, 
            height, 
            f'{int(height):,}',  # Format with commas
            color='black', 
            ha='center', 
            va='bottom', 
            fontsize=10
        )

for container in hist.containers:
    hist.bar_label(container, fmt='%d', label_type='edge', padding=3, bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))

hist.set_title("Climate Focusing Event: Climate Related News Headlines")
hist.set_xlabel("")
hist.set_ylabel("Headlines")
ax.tick_params(axis='x')
ax.grid(True)
ax.set_facecolor("white")

formatter = FuncFormatter(lambda x, _: f'{int(x):,}')
ax.yaxis.set_major_formatter(formatter)


# Set the border (box) around the entire plot
for spine in ax.spines.values():
    spine.set_edgecolor('black')  # Set the color of the border to black
    spine.set_linewidth(1)  # Set the width of the border

plt.tight_layout()
plt.savefig("Climate Focusing Events - Climate Related News Headlines.png",dpi=2500)
plt.show();

# %% [markdown]
# ## 6. Creating A Word Cloud Based on The Documents

# %%
clean_posts = corpus['clean text'].to_list()

# %%
post_text = " ".join(clean_posts)
headline_text = " ".join(news)

import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np

# %%
# Create an elliptical mask
x, y = np.ogrid[:800, :800]
mask = (x - 400)**2 / 2**2 + (y - 400)**2 / 1.5**2 > 380**2  # Creates an oval shape
mask = mask.astype(int)  # Convert to 0s and 1s

# Create a WordCloud object with stopwords, title, and oval shape
wordcloud = WordCloud(
    width=2000,
    height=1000,
    background_color='white',
    colormap='viridis',
    stopwords=stop_words,
    mask=mask,
    scale=10
).generate(post_text)

# Plot the WordCloud
plt.figure(figsize=(10, 5), dpi=300)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # Hide axes
plt.title("Climate Focusing Event:\nBlueSky Climate Posts", fontsize=16, fontweight='bold', pad=20)  # Add title
plt.show()


wordcloud.to_file("Climate Focusing Event - Climate Post Word Cloud.png")

# %%
# Create an elliptical mask
x, y = np.ogrid[:800, :800]
mask = (x - 400)**2 / 2**2 + (y - 400)**2 / 1.5**2 > 380**2  # Creates an oval shape
mask = mask.astype(int)  # Convert to 0s and 1s

# Create a WordCloud object with stopwords, title, and oval shape
wordcloud = WordCloud(
    width=2000,
    height=1000,
    background_color='white',
    colormap='viridis',
    stopwords=stop_words,
    mask=mask,
    scale=10
).generate(headline_text)

# Plot the WordCloud
plt.figure(figsize=(10, 5), dpi=300)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # Hide axes
plt.title("Climate Focusing Event:\nClimate News Headlines", fontsize=16, fontweight='bold', pad=20)  # Add title
plt.show()


wordcloud.to_file("Climate Focusing Event - Climate News Headlines Word Cloud.png")

# %% [markdown]
# ## 7. Calculating Table Values

# %%
values ## For Newspaper
# Out:
#                Dictionary  Total Frequency  Average Topic Size  \
# 6     Climate\nResilience               54            4.909091
# 4         Climate\nAction               50            5.555556
# 5  Environmental\nJustice               49            3.500000
# 0         Climate\nChange               46            4.600000
# 1      Policy\nManagement               15            0.600000
# 2              Republican                0            0.000000
# 3                Democrat                0            0.000000
#
#    Maximum Topic Size  Minimum Topic Size       perc
# 6                40.0                 0.0  54.545455
# 4                40.0                 0.0  50.505051
# 5                40.0                 0.0  49.494949
# 0                40.0                 0.0  46.464646
# 1                 5.0                 0.0  15.151515
# 2                 0.0                 0.0   0.000000
# 3                 0.0                 0.0   0.000000

# %%
values['perc'] = (values['Total Frequency'] / 99)*100

# %%
values ## For Posts
# Out:
#                Dictionary  Total Frequency  Average Topic Size  \
# 5  Environmental\nJustice             8706          621.857143
# 1      Policy\nManagement             8670          346.800000
# 6     Climate\nResilience             8115          737.727273
# 4         Climate\nAction             6918          768.666667
# 0         Climate\nChange             6006          600.600000
# 2              Republican             4942          549.111111
# 3                Democrat             3894          556.285714
#
#    Maximum Topic Size  Minimum Topic Size   perc
# 5              1683.0                30.0  31.69
# 1              1095.0                28.0  31.56
# 6              1683.0                26.0  29.54
# 4              1683.0                70.0  25.18
# 0              1683.0               106.0  21.86
# 2              2080.0                24.0  17.99
# 3              2080.0                28.0  14.17

# %%
values['perc'] = round((values['Total Frequency'] / 27471)*100,2)

# %%
len(clean_posts)
# Out:
# 27471
