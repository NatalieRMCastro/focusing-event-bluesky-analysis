# %% [markdown]
# # Blue Sky Scraper
# ---
# Author: Natalie Castro
# Affiliation: University of Colorado at Boulder
#
# The purpose of this notebook is to use the BlueSky Post scraper, developed by DeepFates and hosted at this [GitHub Repository](https://github.com/deepfates/bsky-scraper) to then analyze and posts related to climate change in current windows of opportunity

# %% [markdown]
# ## 1. Environment Creation
#
# ### 1.1 Library Import

# %%
''' BLUESKY POSTS '''
from atproto import Client

''' REQUIRED FOR SCRAPE.PY '''
from atproto import FirehoseSubscribeReposClient, parse_subscribe_repos_message, CAR, IdResolver, DidInMemoryCache
import json
import time
import argparse
from datetime import datetime
import multiprocessing
import sys
import signal

''' PARSING THE DATA '''
import json

# %% [markdown]
# ## 2. Data Collection

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 2373934 posts in 30375.06 seconds
# Average rate: 78.2 posts/sec
# Output saved to: bluesky_posts_20250109_085956.jsonl
#
# Collection complete!
# Collected 2373934 posts in 30375.06 seconds
# Average rate: 78.2 posts/sec
# Output saved to: bluesky_posts_20250109_085956.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 2806863 posts in 50737.10 seconds
# Average rate: 55.3 posts/sec
# Output saved to: bluesky_posts_20250109_173659.jsonl
#
# Collection complete!
# Collected 2806863 posts in 50737.10 seconds
# Average rate: 55.3 posts/sec
# Output saved to: bluesky_posts_20250109_173659.jsonl

# %% [markdown]
# ### january 20th

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 18700 posts in 263.36 seconds
# Average rate: 71.0 posts/sec
# Output saved to: bluesky_posts_20250120_093845.jsonl
#
# Collection complete!
# Collected 18700 posts in 263.36 seconds
# Average rate: 71.0 posts/sec
# Output saved to: bluesky_posts_20250120_093845.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\university\research\data activism\scrape.py:239
#     236 args = parser.parse_args()
#     238 archiver = FirehoseScraper(output_file=args.output, verbose=args.verbose, num_workers=args.workers)
# --> 239 archiver.start_collection(duration_seconds=args.time, post_limit=args.number)
#
# File ~\OneDrive\university\research\data activism\scrape.py:142, in FirehoseScraper.start_collection(self, duration_seconds, post_limit)
#     130 for _ in range(self.num_workers):
#     131     p = multiprocessing.Process(
#     132         target=worker_process,
#     133         args=(
#    (...)
#     140         )
#     141     )
# --> 142     p.start()
#     143     self.workers.append(p)
#     146 # Handle KeyboardInterrupt in the main process
#
# File ~\miniconda3\lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~\miniconda3\lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~\miniconda3\lib\multiprocessing\context.py:336, in SpawnProcess._Popen(process_obj)
#     333 @staticmethod
#     334 def _Popen(process_obj):
#     335     from .popen_spawn_win32 import Popen
# --> 336     return Popen(process_obj)
#
# File ~\miniconda3\lib\multiprocessing\popen_spawn_win32.py:45, in Popen.__init__(self, process_obj)
#      44 def __init__(self, process_obj):
# ---> 45     prep_data = spawn.get_preparation_data(process_obj._name)
#      47     # read end of pipe will be duplicated by the child process
#      48     # -- see spawn_main() in spawn.py.
#      49     #
#      50     # bpo-33929: Previously, the read end of pipe was "stolen" by the child
#      51     # process, but it leaked a handle if the child process had been
#      52     # terminated before it could steal the handle from the parent process.
#      53     rhandle, whandle = _winapi.CreatePipe(None, 0)
#
# File ~\miniconda3\lib\multiprocessing\spawn.py:183, in get_preparation_data(name)
#     180 # Figure out whether to initialise main in the subprocess as a module
#     181 # or through direct execution (or to leave it alone entirely)
#     182 main_module = sys.modules['__main__']
# --> 183 main_mod_name = getattr(main_module.__spec__, "name", None)
#     184 if main_mod_name is not None:
#     185     d['init_main_from_name'] = main_mod_name
#
# AttributeError: module '__main__' has no attribute '__spec__'

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 33813 posts in 429.18 seconds
# Average rate: 78.8 posts/sec
# Output saved to: bluesky_posts_20250120_104545.jsonl
#
# Collection complete!
# Collected 33813 posts in 429.18 seconds
# Average rate: 78.8 posts/sec
# Output saved to: bluesky_posts_20250120_104545.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 73087 posts in 870.87 seconds
# Average rate: 83.9 posts/sec
# Output saved to: bluesky_posts_20250120_105644.jsonl
#
# Collection complete!
# Collected 73087 posts in 870.87 seconds
# Average rate: 83.9 posts/sec
# Output saved to: bluesky_posts_20250120_105644.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 61941 posts in 824.32 seconds
# Average rate: 75.1 posts/sec
# Output saved to: bluesky_posts_20250120_111308.jsonl
#
# Collection complete!
# Collected 61941 posts in 824.32 seconds
# Average rate: 75.1 posts/sec
# Output saved to: bluesky_posts_20250120_111308.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 6725 posts in 99.97 seconds
# Average rate: 67.3 posts/sec
# Output saved to: bluesky_posts_20250120_112836.jsonl
#
# Collection complete!
# Collected 6725 posts in 99.97 seconds
# Average rate: 67.3 posts/sec
# Output saved to: bluesky_posts_20250120_112836.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 91127 posts in 1157.26 seconds
# Average rate: 78.7 posts/sec
# Output saved to: bluesky_posts_20250120_115640.jsonl
#
# Collection complete!
# Collected 91127 posts in 1157.26 seconds
# Average rate: 78.7 posts/sec
# Output saved to: bluesky_posts_20250120_115640.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 31569 posts in 408.26 seconds
# Average rate: 77.3 posts/sec
# Output saved to: bluesky_posts_20250120_121747.jsonl
#
# Collection complete!
# Collected 31569 posts in 408.26 seconds
# Average rate: 77.3 posts/sec
# Output saved to: bluesky_posts_20250120_121747.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 7330 posts in 109.95 seconds
# Average rate: 66.7 posts/sec
# Output saved to: bluesky_posts_20250120_122535.jsonl
#
# Collection complete!
# Collected 7330 posts in 109.95 seconds
# Average rate: 66.7 posts/sec
# Output saved to: bluesky_posts_20250120_122535.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 5510 posts in 93.90 seconds
# Average rate: 58.7 posts/sec
# Output saved to: bluesky_posts_20250120_122947.jsonl
#
# Collection complete!
# Collected 5510 posts in 93.90 seconds
# Average rate: 58.7 posts/sec
# Output saved to: bluesky_posts_20250120_122947.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 18405 posts in 249.08 seconds
# Average rate: 73.9 posts/sec
# Output saved to: bluesky_posts_20250120_123540.jsonl
#
# Collection complete!
# Collected 18405 posts in 249.08 seconds
# Average rate: 73.9 posts/sec
# Output saved to: bluesky_posts_20250120_123540.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 14526 posts in 201.64 seconds
# Average rate: 72.0 posts/sec
# Output saved to: bluesky_posts_20250120_124104.jsonl
#
# Collection complete!
# Collected 14526 posts in 201.64 seconds
# Average rate: 72.0 posts/sec
# Output saved to: bluesky_posts_20250120_124104.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 18184 posts in 263.51 seconds
# Average rate: 69.0 posts/sec
# Output saved to: bluesky_posts_20250120_124753.jsonl
#
# Collection complete!
# Collected 18184 posts in 263.51 seconds
# Average rate: 69.0 posts/sec
# Output saved to: bluesky_posts_20250120_124753.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 12060 posts in 167.39 seconds
# Average rate: 72.0 posts/sec
# Output saved to: bluesky_posts_20250120_125400.jsonl
#
# Collection complete!
# Collected 12060 posts in 167.39 seconds
# Average rate: 72.0 posts/sec
# Output saved to: bluesky_posts_20250120_125400.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 78319 posts in 898.11 seconds
# Average rate: 87.2 posts/sec
# Output saved to: bluesky_posts_20250120_125722.jsonl
#
# Collection complete!
# Collected 78319 posts in 898.11 seconds
# Average rate: 87.2 posts/sec
# Output saved to: bluesky_posts_20250120_125722.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 23353 posts in 312.68 seconds
# Average rate: 74.7 posts/sec
# Output saved to: bluesky_posts_20250120_131321.jsonl
#
# Collection complete!
# Collected 23353 posts in 312.68 seconds
# Average rate: 74.7 posts/sec
# Output saved to: bluesky_posts_20250120_131321.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 11009 posts in 159.35 seconds
# Average rate: 69.1 posts/sec
# Output saved to: bluesky_posts_20250120_131950.jsonl
#
# Collection complete!
# Collected 11009 posts in 159.35 seconds
# Average rate: 69.1 posts/sec
# Output saved to: bluesky_posts_20250120_131950.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 9755 posts in 134.18 seconds
# Average rate: 72.7 posts/sec
# Output saved to: bluesky_posts_20250120_132431.jsonl
#
# Collection complete!
# Collected 9755 posts in 134.18 seconds
# Average rate: 72.7 posts/sec
# Output saved to: bluesky_posts_20250120_132431.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 4288 posts in 79.85 seconds
# Average rate: 53.7 posts/sec
# Output saved to: bluesky_posts_20250120_132752.jsonl
#
# Collection complete!
# Collected 4288 posts in 79.85 seconds
# Average rate: 53.7 posts/sec
# Output saved to: bluesky_posts_20250120_132752.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 3304 posts in 79.79 seconds
# Average rate: 41.4 posts/sec
# Output saved to: bluesky_posts_20250120_205459.jsonl
#
# Collection complete!
# Collected 3304 posts in 79.79 seconds
# Average rate: 41.4 posts/sec
# Output saved to: bluesky_posts_20250120_205459.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 58951 posts in 877.31 seconds
# Average rate: 67.2 posts/sec
# Output saved to: bluesky_posts_20250120_205911.jsonl
#
# Collection complete!
# Collected 58951 posts in 877.31 seconds
# Average rate: 67.2 posts/sec
# Output saved to: bluesky_posts_20250120_205911.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 33228 posts in 545.14 seconds
# Average rate: 61.0 posts/sec
# Output saved to: bluesky_posts_20250120_211614.jsonl
#
# Collection complete!
# Collected 33228 posts in 545.14 seconds
# Average rate: 61.0 posts/sec
# Output saved to: bluesky_posts_20250120_211614.jsonl

# %%
# %run scrape.py
# Out:
# Starting collection...
#
# Client process exited unexpectedly.
#
# Collection complete!
# Collected 2204366 posts in 36580.98 seconds
# Average rate: 60.3 posts/sec
# Output saved to: bluesky_posts_20250120_212804.jsonl
#
# Collection complete!
# Collected 2204366 posts in 36580.98 seconds
# Average rate: 60.3 posts/sec
# Output saved to: bluesky_posts_20250120_212804.jsonl
